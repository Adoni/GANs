# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pickle

# %%
def plot_errors(filename):
    errG, errD = pickle.load(open(filename, 'rb'), encoding='latin1')
    plt.plot(errG)
    plt.show()

# %%
plot_errors('./results/Sinkhorn_MLP/MNIST/0.10/loss.pkl')

# %%
plot_errors('/Users/sunxiaofei/Downloads/Sinkhorn_MLP/MNIST/1.00/loss.pkl')

# %%
plot_errors('/Users/sunxiaofei/Downloads/Sinkhorn_DC/MNIST/1.00/loss.pkl')

# %%
plot_errors('/Users/sunxiaofei/Downloads/Sinkhorn_DC/LSUN/10.00/loss.pkl')

# %%
plot_errors('/Users/sunxiaofei/Downloads/Sinkhorn_DC/MNIST/1.00/loss.pkl')
